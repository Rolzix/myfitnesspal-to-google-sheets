# %%
import datetime
import myfitnesspal
import gspread

mfp = myfitnesspal.Client()
# Replace with your own path, default is current directory
sheets = gspread.service_account("./service_account.json")

# Replace "HealthTracking" with the name of your spreadsheet
sh = sheets.open("HealthTracking")

# Replace "Sheet1" with the name of your worksheet
worksheet = sh.worksheet("2014")

# Get the last date in the first column
if len(worksheet.col_values(1)) < 1:  # Check if the first cell is empty
    print("First cell is empty")
    worksheet.update(
        f"A1", [["Date", "Total calories", "Carbohydrates", "Fat", "Protein"]]
    )  # Update the first row with the column names
    worksheet.update(f"A2", "2023-01-01")  # Update the first data cell with the date
    last_date_str = worksheet.col_values(1)[-1]
else:
    last_date_str = worksheet.col_values(1)[-1]
print(f"Last date as string in the worksheet is {last_date_str}")

# Convert the last date from string to datetime format
last_date = datetime.datetime.strptime(last_date_str, "%Y-%m-%d").date()
print(f"Last date in the worksheet is {last_date}")

# Get the index of the last date in the col_values list
start_index = worksheet.col_values(1).index(last_date_str) + 1
print(f"Index of the last date in the worksheet is {start_index}")

# Start from the row after the last date
start_date = last_date + datetime.timedelta(days=0)
print(f"Starting from {start_date.strftime('%Y-%m-%d')}")

# End at today's date
end_date = datetime.date.today()
print(f"Ending at {end_date.strftime('%Y-%m-%d')}")

# Change this number to the maximum number of rows you want to update
max_num_updated = 9999

i = 1  # counter variable

print("Starting loop")

for date in (
    start_date + datetime.timedelta(n)
    for n in range(0, (end_date - start_date).days + 1)
):
    # Check if the number of updated rows is greater than max_num_updated
    if max_num_updated < 1:
        print("Stopping because maximum number to update is reached")
        break  # Exit the loop if the condition is true
    print(f"Update operation number {i}")

    i += 1

    try:
        # Get the MyFitnessPal data for the specified date
        day = mfp.get_date(date.year, date.month, date.day)
        print(f"Data from MyFitnessPal is {day}")
        print(
            f"Updating worksheet for {(date - start_date).days + start_index , 1, date.strftime('%Y-%m-%d')} <-- (row, col, date))"
        )
        # Update the worksheet with the MyFitnessPal data for the current date
        worksheet.update(
            f"A{(date - start_date).days + start_index}",
            [
                [
                    date.strftime("%Y-%m-%d"),
                    day.totals["calories"],
                    day.totals["carbohydrates"],
                    day.totals["fat"],
                    day.totals["protein"],
                ]
            ],
        )
        # worksheet.update_cell((date - start_date).days + start_index , 1, date.strftime('%Y-%m-%d'))  # Update the first cell with the date
        # worksheet.update_cell((date - start_date).days + start_index, 2, day.totals['calories'])  # Update the second cell with the total calories
        # worksheet.update_cell((date - start_date).days + start_index, 3, day.totals['carbohydrates'])  # Update the third cell with the total carbohydrates
        # worksheet.update_cell((date - start_date).days + start_index, 4, day.totals['fat'])  # Update the fourth cell with the total fat
        # worksheet.update_cell((date - start_date).days + start_index, 5, day.totals['protein'])  # Update the fifth cell with the total protein
        print(f"Successfully updated worksheet for {date.strftime('%Y-%m-%d')}")
        max_num_updated -= 1  # Decrement the counter variable

    except:
        print(f"Something went wrong or no data for {date.strftime('%Y-%m-%d')}")
        print(f"Data from MyFitnessPal was {day}")
        # Update the first cell with the date
        worksheet.update(
            f"A{(date - start_date).days + start_index}", [[date.strftime("%Y-%m-%d")]]
        )


print(f"updated {i} rows, happy tracking!")
# Out:
# Last date as string in the worksheet is 2024-01-01
# Last date in the worksheet is 2024-01-01
# Index of the last date in the worksheet is 2
# Starting from 2024-01-01
# Ending at 2024-01-25
# Starting loop
# Update operation number 1
# Data from MyFitnessPal is 01/01/24 {'calories': 1006.0, 'carbohydrates': 93.0, 'fat': 26.0, 'protein': 100.0}
# Updating worksheet for (2, 1, '2024-01-01') <-- (row, col, date))
# C:\Users\Aki\AppData\Local\Temp\ipykernel_18864\1248989672.py:70: DeprecationWarning: [Deprecated][in version 6.0.0]: Method signature's arguments 'range_name' and 'values' will change their order. We recommend using named arguments for minimal impact. In addition, the argument 'values' will be mandatory of type: 'List[List]'. (ex) Worksheet.update(values = [[]], range_name=)
#   worksheet.update(
# Successfully updated worksheet for 2024-01-01
# Update operation number 2
# Data from MyFitnessPal is 01/02/24 {'calories': 1208.0, 'carbohydrates': 89.0, 'fat': 56.0, 'protein': 86.0}
# Updating worksheet for (3, 1, '2024-01-02') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-02
# Update operation number 3
# Data from MyFitnessPal is 01/03/24 {}
# Updating worksheet for (4, 1, '2024-01-03') <-- (row, col, date))
# Something went wrong or no data for 2024-01-03
# Data from MyFitnessPal was 01/03/24 {}
# C:\Users\Aki\AppData\Local\Temp\ipykernel_18864\1248989672.py:94: DeprecationWarning: [Deprecated][in version 6.0.0]: Method signature's arguments 'range_name' and 'values' will change their order. We recommend using named arguments for minimal impact. In addition, the argument 'values' will be mandatory of type: 'List[List]'. (ex) Worksheet.update(values = [[]], range_name=)
#   worksheet.update(
# Update operation number 4
# Data from MyFitnessPal is 01/04/24 {}
# Updating worksheet for (5, 1, '2024-01-04') <-- (row, col, date))
# Something went wrong or no data for 2024-01-04
# Data from MyFitnessPal was 01/04/24 {}
# Update operation number 5
# Data from MyFitnessPal is 01/05/24 {}
# Updating worksheet for (6, 1, '2024-01-05') <-- (row, col, date))
# Something went wrong or no data for 2024-01-05
# Data from MyFitnessPal was 01/05/24 {}
# Update operation number 6
# Data from MyFitnessPal is 01/06/24 {}
# Updating worksheet for (7, 1, '2024-01-06') <-- (row, col, date))
# Something went wrong or no data for 2024-01-06
# Data from MyFitnessPal was 01/06/24 {}
# Update operation number 7
# Data from MyFitnessPal is 01/07/24 {}
# Updating worksheet for (8, 1, '2024-01-07') <-- (row, col, date))
# Something went wrong or no data for 2024-01-07
# Data from MyFitnessPal was 01/07/24 {}
# Update operation number 8
# Data from MyFitnessPal is 01/08/24 {'calories': 1139.0, 'carbohydrates': 40.0, 'fat': 57.0, 'protein': 116.0}
# Updating worksheet for (9, 1, '2024-01-08') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-08
# Update operation number 9
# Data from MyFitnessPal is 01/09/24 {'calories': 2946.0, 'carbohydrates': 266.0, 'fat': 132.0, 'protein': 169.0}
# Updating worksheet for (10, 1, '2024-01-09') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-09
# Update operation number 10
# Data from MyFitnessPal is 01/10/24 {'calories': 2017.0, 'carbohydrates': 407.0, 'fat': 13.0, 'protein': 57.0}
# Updating worksheet for (11, 1, '2024-01-10') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-10
# Update operation number 11
# Data from MyFitnessPal is 01/11/24 {'calories': 1939.0, 'carbohydrates': 166.0, 'fat': 103.0, 'protein': 85.0}
# Updating worksheet for (12, 1, '2024-01-11') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-11
# Update operation number 12
# Data from MyFitnessPal is 01/12/24 {'calories': 2922.0, 'carbohydrates': 420.0, 'fat': 71.0, 'protein': 126.0}
# Updating worksheet for (13, 1, '2024-01-12') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-12
# Update operation number 13
# Data from MyFitnessPal is 01/13/24 {'calories': 3587.0, 'carbohydrates': 464.0, 'fat': 149.0, 'protein': 86.0}
# Updating worksheet for (14, 1, '2024-01-13') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-13
# Update operation number 14
# Data from MyFitnessPal is 01/14/24 {'calories': 3414.0, 'carbohydrates': 368.0, 'fat': 185.0, 'protein': 62.0}
# Updating worksheet for (15, 1, '2024-01-14') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-14
# Update operation number 15
# Data from MyFitnessPal is 01/15/24 {'calories': 2469.0, 'carbohydrates': 189.0, 'fat': 137.0, 'protein': 109.0}
# Updating worksheet for (16, 1, '2024-01-15') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-15
# Update operation number 16
# Data from MyFitnessPal is 01/16/24 {'calories': 2391.0, 'carbohydrates': 179.0, 'fat': 133.0, 'protein': 115.0}
# Updating worksheet for (17, 1, '2024-01-16') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-16
# Update operation number 17
# Data from MyFitnessPal is 01/17/24 {'calories': 2190.0, 'carbohydrates': 221.0, 'fat': 91.0, 'protein': 118.0}
# Updating worksheet for (18, 1, '2024-01-17') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-17
# Update operation number 18
# Data from MyFitnessPal is 01/18/24 {'calories': 2231.0, 'carbohydrates': 293.0, 'fat': 73.0, 'protein': 99.0}
# Updating worksheet for (19, 1, '2024-01-18') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-18
# Update operation number 19
# Data from MyFitnessPal is 01/19/24 {'calories': 2142.0, 'carbohydrates': 324.0, 'fat': 52.0, 'protein': 96.0}
# Updating worksheet for (20, 1, '2024-01-19') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-19
# Update operation number 20
# Data from MyFitnessPal is 01/20/24 {'calories': 5036.0, 'carbohydrates': 680.0, 'fat': 210.0, 'protein': 95.0}
# Updating worksheet for (21, 1, '2024-01-20') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-20
# Update operation number 21
# Data from MyFitnessPal is 01/21/24 {'calories': 3263.0, 'carbohydrates': 311.0, 'fat': 198.0, 'protein': 58.0}
# Updating worksheet for (22, 1, '2024-01-21') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-21
# Update operation number 22
# Data from MyFitnessPal is 01/22/24 {'calories': 2828.0, 'carbohydrates': 370.0, 'fat': 99.0, 'protein': 109.0}
# Updating worksheet for (23, 1, '2024-01-22') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-22
# Update operation number 23
# Data from MyFitnessPal is 01/23/24 {'calories': 2592.0, 'carbohydrates': 352.0, 'fat': 75.0, 'protein': 114.0}
# Updating worksheet for (24, 1, '2024-01-23') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-23
# Update operation number 24
# Data from MyFitnessPal is 01/24/24 {'calories': 1924.0, 'carbohydrates': 118.0, 'fat': 94.0, 'protein': 138.0}
# Updating worksheet for (25, 1, '2024-01-24') <-- (row, col, date))
# Successfully updated worksheet for 2024-01-24
# Update operation number 25
# Data from MyFitnessPal is 01/25/24 {}
# Updating worksheet for (26, 1, '2024-01-25') <-- (row, col, date))
# Something went wrong or no data for 2024-01-25
# Data from MyFitnessPal was 01/25/24 {}
# updated 26 rows, happy tracking!
